# %% [markdown]
# # Spotify EDA
#
# The overall goal of this personal project is to use Spotify listening data to practice organizing and cleaning data, running some exploratory analyses, and implementing some basic machine learning models.
#
# This notebook primarily deals with getting the audio features of songs (by querying the Spotify API, via [spotipy](https://spotipy.readthedocs.io/en/2.16.1/) library) and organizing the information into a dataframe for easier use.

# %%
import pandas as pd

# %% [markdown]
# ## Read in streaming data

# %%
# read in streaming data as pd dataframes
data_df1 = pd.read_json('MyData/StreamingHistory0.json')
data_df2 = pd.read_json('MyData/StreamingHistory1.json')

data = pd.concat([data_df1, data_df2]).reset_index() #concat into single df
data['index'] = data.index # so that 'index' numbering is continuous
data.rename({'index': 'orig_index'}, axis=1, inplace=True) # may be useful to keep track of this
data
# Out:
#        orig_index           endTime artistName                 trackName  \
# 0               0  2019-10-09 00:02      TWICE              Breakthrough
# 1               1  2019-10-09 00:05       GOT7          너란 Girl Magnetic
# 2               2  2019-10-09 00:09      SE7EN           Better Together
# 3               3  2019-10-09 00:12       GOT7                      Look
# 4               4  2019-10-09 00:15      TWICE               KNOCK KNOCK
# ...           ...               ...        ...                       ...
# 17590       17590  2020-10-09 21:46    TAEYANG  눈,코,입 (Eyes, Nose, Lips)
# 17591       17591  2020-10-09 21:50      TWICE                  CHEER UP
# 17592       17592  2020-10-09 21:53     SEULGI                 Wow Thing
# 17593       17593  2020-10-09 21:56     Hyolyn                       BAE
# 17594       17594  2020-10-09 22:00        BTS                  Dynamite
#
#        msPlayed
# 0        217650
# 1        203084
# 2        218120
# 3        194535
# 4        195753
# ...         ...
# 17590    229989
# 17591    208853
# 17592    171998
# 17593    206566
# 17594    199053
#
# [17595 rows x 5 columns]

# %% [markdown]
# ## Start with some very basic cleanup

# %%
# have some unknowns
is_unknown = data['trackName'] == 'Unknown Track'
print('{} out of {} plays are unknown'.format(is_unknown.sum(), len(data)))
data[is_unknown].head()
# Out:
# 43 out of 17595 plays are unknown
#        orig_index           endTime      artistName      trackName  msPlayed
# 16884       16884  2020-09-25 18:11  Unknown Artist  Unknown Track   2004626
# 16885       16885  2020-09-26 00:32  Unknown Artist  Unknown Track   1968807
# 16887       16887  2020-09-26 02:14  Unknown Artist  Unknown Track   2215833
# 17009       17009  2020-10-02 16:28  Unknown Artist  Unknown Track    172182
# 17010       17010  2020-10-02 16:31  Unknown Artist  Unknown Track    143343

# %%
# filter out unknowns
data = data[~is_unknown]
print(str(len(data)) + ' "known" song plays')
# Out:
# 17552 "known" song plays

# %%
#check play count; filter out songs that were played only once
artist_track = data['artistName'] + '__' + data['trackName'] #assuming no artist/song has __ in its title; use to split later
play_counts = artist_track.value_counts()
num_played_once = (play_counts == 1).sum()

print('{}/{} songs were played only once in the past year.\n\
Going to ignore these from here on out.\n'.format(num_played_once, len(data)))

keep_unique_songs = play_counts[play_counts > 1].index #unique list of songs I've played more than once
data_idxs = [idx for idx,song in enumerate(artist_track.values) if song in keep_unique_songs] #corresponding idxs in data df
data_filt = data.iloc[idxs].reset_index(drop=True)
data_filt
# Out:
# 2136/17552 songs were played only once in the past year.
# Going to ignore these from here on out.
#        orig_index           endTime artistName                 trackName  \
# 0               0  2019-10-09 00:02      TWICE              Breakthrough
# 1               1  2019-10-09 00:05       GOT7          너란 Girl Magnetic
# 2               2  2019-10-09 00:09      SE7EN           Better Together
# 3               3  2019-10-09 00:12       GOT7                      Look
# 4               4  2019-10-09 00:15      TWICE               KNOCK KNOCK
# ...           ...               ...        ...                       ...
# 15411       17590  2020-10-09 21:46    TAEYANG  눈,코,입 (Eyes, Nose, Lips)
# 15412       17591  2020-10-09 21:50      TWICE                  CHEER UP
# 15413       17592  2020-10-09 21:53     SEULGI                 Wow Thing
# 15414       17593  2020-10-09 21:56     Hyolyn                       BAE
# 15415       17594  2020-10-09 22:00        BTS                  Dynamite
#
#        msPlayed
# 0        217650
# 1        203084
# 2        218120
# 3        194535
# 4        195753
# ...         ...
# 15411    229989
# 15412    208853
# 15413    171998
# 15414    206566
# 15415    199053
#
# [15416 rows x 5 columns]

# %% [markdown]
# ## Search each song to get its Spotify ID
# Each track's Spotify ID is needed in order to query its audio features; the main way to get a track's Spotify ID is to search for it.

# %%
# use spotipy library to interface with Spotify API
import spotipy 
from spotipy.oauth2 import SpotifyClientCredentials

from time import sleep

# %%
# fill in with your client ID & secret key
clientID = '<client ID here>'
secret = '<secret here>'

# %%
client_credentials_manager = SpotifyClientCredentials(client_id=clientID, client_secret=secret)
sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

# %% [markdown]
# search_for_songs uses spotipy to access the Spotify Search API to search for individual songs, using the artist and song name for each song.
#
# A few notes on the function:
# - Songs/artists with single/double quotation marks in the title are not searched correctly. Backslashes cannot be used as escapes; rather, removing the quotation mark is sufficient, so this is what search_for_songs does. (FWIW: &, -, (, and ) characters are fine to leave in; don't prevent match.)
# - Searching with artist + track name does not always return the correct song first. search_for_songs includes user-side check as part of the search - if the artist + track name of the first search result does not match the song of interest, the function will ask the user Y/N if a given search result is the correct match, cycling through the search results until a correct match is found. Note that the current version of this isn't particularly robust - e.g., there isn't a way to go back/recover if user makes a mistake.
# - Mismatches are stored in a dictionary that is saved and can be used for future reference. This dictionary logs the query used and the index of the correct search result, which search_for_songs can use to automatically find correct matches. Notably, this usage is dependent on Spotify returning search results in the same order for a given query, which isn't a safe assumption to make forever.
#
# See [Spotify API documentation](https://developer.spotify.com/documentation/web-api/reference/search/search/#writing-a-query---guidelines) for more information on writing search queries

# %%
# songs should be a list of '<artist>__<track>' strings representing individual songs
# mismatches is a dict, with <artist__<track> strings as keys and the "match idx" as values - the idx for the correct search result when queried
# search_for_songs uses the artist + track names to query each song 
# prompts user check if the first result from the search query doesn't match the artist/track name
# stores correct search results, and keeps track of any mismatches and any songs that weren't found
def search_for_songs(songs, mismatches=None):
    search_results = {}
    no_match = []
    if mismatches is None:
        mismatches = {}
    
    for idx, song in enumerate(songs):       
        #get artist & track name, free of single/double quotes
        artist = song.split('__')[0].replace("'", '').replace('"', '') 
        track = song.split('__')[1].replace("'", '').replace('"', '') 
        
        #search
        query = 'artist:"{}" track:"{}"'.format(artist, track)
        matches = sp.search(q=query, type='track')['tracks']['items'] #search results are stored here

        sleep(.1)
        
        #if search returned a result
        if matches: 
            
            #grab first match
            match = matches[0] 
            matched_artist = match['artists'][0]['name']
            matched_track = match['name']
            
            #check search result 
            if ((song.split('__')[0].lower() == matched_artist.lower()) & 
                (song.split('__')[1].lower() == matched_track.lower())):
                search_results[song] = match #if artist & track name match, then store
                      
            else: #otherwise, if mismatch between artist/track name and search result ..
                if song in mismatches: #if this mismatch has been logged before, use stored info to resolve
                    match_idx = mismatches[song]['match_idx'] 
                    search_results[song] = matches[match_idx] #idx of correct search query result
                
                else: #otherwise, look through search results
                    print('\nMismatch for ' + song)
                    print('Search result: ')
                    print(matched_artist + ' - ' + matched_track)
                    correct = input('Is this correct? Y/N: \n')
                    
                    if correct == 'Y': #if first match actually is correct
                        mismatches[song] = {'query': query, 'match_idx': 0} #store 'mismatch' info
                        search_results[song] = match #store match
                    
                    elif correct == 'N': #if first match is incorrect
                        find_match = 'N'
                        if len(matches) > 1: #if there are more matches
                            for idx, m in enumerate(matches[1:], start=1): #cycle through each option
                                print('How about... ')
                                print(m['artists'][0]['name'] + ' - ' + m['name'])
                                find_match = input('Is this correct? Y/N: \n')
                                
                                if find_match == 'Y': #store correct match when found
                                    search_results[song] = matches[idx]
                                    mismatches[song] = {'query': query, 'match_idx': idx}
                                    break
                            if idx == len(matches)-1 & find_match == 'N': #if reached end of matches & didn't find one
                                no_match.append(song) #store in no_match
                        elif len(matches) == 1:  #if there was only a single (incorrect) match
                            no_match.append(song) #store in no_match
                    
                    elif correct == 'Z': #Z to quit
                        break

        elif not matches: #if no search result
            no_match.append(song)
            
    return search_results, no_match, mismatches

# %%
artist_track_filt = data_filt['artistName'] + '__' + data_filt['trackName']
unique_songs = artist_track_filt.unique()

print('{} unique songs. Search for each and get its spotify ID info..'
      .format(len(unique_songs)))

try:
    mismatches = pd.read_pickle('mismatches.pkl').to_dict(orient='index')
except FileNotFoundError:
    mismatches = None

search_results, no_match, mismatches = search_for_songs(unique_songs, mismatches)
# Out:
# 1505 unique songs. Search for each and get its spotify ID info..
#
# Mismatch for chief.__orion
# Search result:
# The Late Night Chiefs - Orion
# Is this correct? Y/N:
# N
#
# Mismatch for SEVENTEEN__Adore U - Vocal Team Ver.
# Search result:
# SEVENTEEN - Adore U (Vocal Team Ver.)
# Is this correct? Y/N:
# Y
#
# Mismatch for LiSA__Gurenge
# Search result:
# LiSA - Gurenge (Demon Slayer) - Remix
# Is this correct? Y/N:
# N

# %%
# number of unique songs should equal number of search results + songs that weren't matched
print(len(unique_songs))
print(len(search_results) + len(no_match))
# Out:
# 1505
# 1505

# %% [markdown]
# ### Check songs that weren't found - do any of these need to be corrected?

# %%
no_match
# Out:
# ['TWICE__OOH-AHH하게 Like OOH-AHH',
#  'GOT7__Bibouroku',
#  'DAY6__If 〜また逢えたら〜',
#  'William Bolton__Some Love (feat. Jackson Breit)',
#  'ASTRO__그림자',
#  'chief.__orion',
#  'DAY6__君なら',
#  'eaJ’s Music__eaJ - Pinocchio',
#  'eaJ’s Music__eaJ - Guess Not',
#  'eaJ’s Music__eaJ - Otherside',
#  'eaJ’s Music__eaJ - La Trains',
#  'DAY6 Another Songs__Young one - Honesty',
#  'DAY6 Another Songs__eaJ - LA TRAINS (Acoustic Ver.)',
#  'DAY6 Another Songs__Young One - Face to Face',
#  'DAY6 Another Songs__You Were Beautiful (acoustic)',
#  'DAY6 Another Songs__Young One - Talk',
#  'DAY6 Another Songs__Jae - Happy Ending',
#  'DAY6 Another Songs__Jae - Rose',
#  'Yumi Arai__ひこうき雲',
#  'Korean Songs__eaJ - 50 Proof',
#  'DAY6 Another Songs__YOU',
#  'DAY6 Another Songs__eaJ - PINOCCHIO (Acoustic Ver.)',
#  'DAY6 Another Songs__eaJ - Otherside',
#  'DAY6 Solo Project__eaJ - 50 proof',
#  'DAY6 Solo Project__eaJ - Truman',
#  'Part Of Mind__しき の うた',
#  'Bajune Tobeta__テディベアとパスワード ニコラ・コンテ re-mix',
#  'Yoshihisa Hirano__暗殺一家の館',
#  'Taylor Swift__Clean',
#  'NiziU__虹の向こうへ',
#  'LiSA__Gurenge',
#  'LiSA__Datte Atashino Hero']

# %% [markdown]
# In the above list of songs that were not found, a handful are songs should have been matched. Did some experimenting and found alternate titles that would match properly. Fix these entries and update data accordingly. (The remaining "no matches" are either songs that are not well known and therefore decided to be fine to exclude, and/or podcast episodes that should not be included anyway).

# %%
# these songs need to be renamed so that they can be searched properly
fix_these_songs = ['TWICE__OOH-AHH하게 Like OOH-AHH', 'ASTRO__그림자', 'DAY6__君なら', 'DAY6__If 〜また逢えたら〜']

# key = old name, value = new name
rename = {'OOH-AHH하게 Like OOH-AHH': 'Like Ooh-Ahh',
          '그림자': 'Shadow',
          '君なら': '君',
          'If 〜また逢えたら〜': 'If ~'}

data_copy = data_filt.copy()
fixed = []
for song in fix_these_songs:
    track_name = song.split('__')[1]
    
    fix_these = data_copy['trackName'] == track_name #idxes to change
    data_copy.loc[fix_these, 'trackName'] = rename[track_name] 
    
    fixed.append(song.split('__')[0] + '__' + rename[track_name]) #build list of new song names to use in search
    
data_filt = data_copy

# %%
# re-run search using newly renamed songs
search_fixed, _, _ = search_for_songs(fixed)

already_found = [key in search_results for key in search_fixed.keys()]
print(f'\nFYI, {sum(already_found)} renamed song(s) already found in original search_results')
# Out:
# Mismatch for DAY6__君
# Search result:
# DAY6 - 君なら
# Is this correct? Y/N:
# Y
#
# Mismatch for DAY6__If ~
# Search result:
# DAY6 - If 〜また逢えたら〜
# Is this correct? Y/N:
# Y
#
# FYI, 1 renamed song(s) already found in original search_results

# %%
# add new search results from corrected names to original search_results
search_results.update(search_fixed)
print(f'Added {len(search_fixed) - sum(already_found)} items to search results.\n')

print('Effectively {} unique songs to analyze ({} unique songs in dataset, but {} were not found).'.
     format(len(search_results), 
            len(unique_songs), 
            len(no_match) - len(search_fixed) + sum(already_found)))
# Out:
# Added 3 items to search results.
#
# Effectively 1476 unique songs to analyze (1505 unique songs in dataset, but 29 were not found).

# %%
# save mismatches
mismatches_df = pd.DataFrame.from_dict(mismatches, orient='index')
mismatches_df.to_pickle('mismatches.pkl')

# %% [markdown]
# ## Convert search results into dataframe with track, artist, and album info
# Spotify search returned album and artist information for each track as dictionary keys. The blocks below extract this information and convert it into album/artist dataframes, then merges everything in order to have metadata altogether in a single dataframe

# %%
# add artist_track_name; easier to use as unique identifier
artist_track = data_filt['artistName'] + '__' + data_filt['trackName']
data_filt['artist_track_name'] = artist_track

# %%
# convert track info to dataframe
track_info = pd.DataFrame.from_dict(search_results, orient='index').add_prefix('track_')
track_info = track_info.reset_index().rename({'index': 'artist_track_name'}, axis=1)

# pull out 'album' and 'artists' (first artist) dictionaries and convert to dataframe
album_info = pd.DataFrame([search_results[x]['album'] for x in search_results]).add_prefix('album_')
artist_info = pd.DataFrame([search_results[x]['artists'][0] for x in search_results]).add_prefix('artist_')

# %% [markdown]
# Check track, album, and artists dataframes & decide if there are any columns that can be dropped

# %%
album_info.head()
# Out:
#   album_album_type                                      album_artists  \
# 0           single  [{'external_urls': {'spotify': 'https://open.s...
# 1            album  [{'external_urls': {'spotify': 'https://open.s...
# 2            album  [{'external_urls': {'spotify': 'https://open.s...
# 3           single  [{'external_urls': {'spotify': 'https://open.s...
# 4            album  [{'external_urls': {'spotify': 'https://open.s...
#
#                              album_available_markets  \
# 0  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 1  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 2  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 3  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
# 4  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...
#
#                                  album_external_urls  \
# 0  {'spotify': 'https://open.spotify.com/album/7L...
# 1  {'spotify': 'https://open.spotify.com/album/02...
# 2  {'spotify': 'https://open.spotify.com/album/5W...
# 3  {'spotify': 'https://open.spotify.com/album/5a...
# 4  {'spotify': 'https://open.spotify.com/album/3O...
#
#                                           album_href                album_id  \
# 0  https://api.spotify.com/v1/albums/7LWfEiSeue9B...  7LWfEiSeue9BXPbUOH34q6
# 1  https://api.spotify.com/v1/albums/02dvCQbuBKdU...  02dvCQbuBKdU1QHHGtrCHy
# 2  https://api.spotify.com/v1/albums/5WdFwkGiwtXM...  5WdFwkGiwtXM4DiXxl02CM
# 3  https://api.spotify.com/v1/albums/5aCJKuo69SGb...  5aCJKuo69SGbveapvkSYMW
# 4  https://api.spotify.com/v1/albums/3O7HQtCnGoaX...  3O7HQtCnGoaXMxXLkspFL8
#
#                                         album_images            album_name  \
# 0  [{'height': 640, 'url': 'https://i.scdn.co/ima...          Breakthrough
# 1  [{'height': 640, 'url': 'https://i.scdn.co/ima...              Identify
# 2  [{'height': 640, 'url': 'https://i.scdn.co/ima...        Digital Bounce
# 3  [{'height': 640, 'url': 'https://i.scdn.co/ima...           Eyes On You
# 4  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Twicecoaster: Lane 2
#
#   album_release_date album_release_date_precision  album_total_tracks  \
# 0         2019-06-12                          day                   1
# 1         2014-11-28                          day                  11
# 2               2010                         year                   7
# 3         2018-03-12                          day                   6
# 4         2017-02-20                          day                   9
#
#   album_type                             album_uri
# 0      album  spotify:album:7LWfEiSeue9BXPbUOH34q6
# 1      album  spotify:album:02dvCQbuBKdU1QHHGtrCHy
# 2      album  spotify:album:5WdFwkGiwtXM4DiXxl02CM
# 3      album  spotify:album:5aCJKuo69SGbveapvkSYMW
# 4      album  spotify:album:3O7HQtCnGoaXMxXLkspFL8

# %%
# drop..
# 'album_artists' - already have track artists; not going to worry about album artists
# 'album_available_markets' - don't care about this
# 'album_type' - no useful info
# 
# + rename 'album_album_type' to 'album_type'
album_info.drop(['album_artists', 'album_available_markets', 'album_type'], axis=1, inplace=True)
album_info.rename(columns={'album_album_type': 'album_type'}, inplace=True)

# %%
artist_info.head()
# Out:
#                                 artist_external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/7...
# 1  {'spotify': 'https://open.spotify.com/artist/6...
# 2  {'spotify': 'https://open.spotify.com/artist/1...
# 3  {'spotify': 'https://open.spotify.com/artist/6...
# 4  {'spotify': 'https://open.spotify.com/artist/7...
#
#                                          artist_href               artist_id  \
# 0  https://api.spotify.com/v1/artists/7n2Ycct7Bei...  7n2Ycct7Beij7Dj7meI4X0
# 1  https://api.spotify.com/v1/artists/6nfDaffa50m...  6nfDaffa50mKtEOwR8g4df
# 2  https://api.spotify.com/v1/artists/14yLuCwlBqt...  14yLuCwlBqteUdBqx9soJV
# 3  https://api.spotify.com/v1/artists/6nfDaffa50m...  6nfDaffa50mKtEOwR8g4df
# 4  https://api.spotify.com/v1/artists/7n2Ycct7Bei...  7n2Ycct7Beij7Dj7meI4X0
#
#   artist_name artist_type                             artist_uri
# 0       TWICE      artist  spotify:artist:7n2Ycct7Beij7Dj7meI4X0
# 1        GOT7      artist  spotify:artist:6nfDaffa50mKtEOwR8g4df
# 2       SE7EN      artist  spotify:artist:14yLuCwlBqteUdBqx9soJV
# 3        GOT7      artist  spotify:artist:6nfDaffa50mKtEOwR8g4df
# 4       TWICE      artist  spotify:artist:7n2Ycct7Beij7Dj7meI4X0

# %%
# drop'artist_type' - no useful info
artist_info.drop('artist_type', axis=1, inplace=True)

# %%
track_info.head()
# Out:
#         artist_track_name                                        track_album  \
# 0     TWICE__Breakthrough  {'album_type': 'single', 'artists': [{'externa...
# 1  GOT7__너란 Girl Magnetic  {'album_type': 'album', 'artists': [{'external...
# 2  SE7EN__Better Together  {'album_type': 'album', 'artists': [{'external...
# 3              GOT7__Look  {'album_type': 'single', 'artists': [{'externa...
# 4      TWICE__KNOCK KNOCK  {'album_type': 'album', 'artists': [{'external...
#
#                                        track_artists  \
# 0  [{'external_urls': {'spotify': 'https://open.s...
# 1  [{'external_urls': {'spotify': 'https://open.s...
# 2  [{'external_urls': {'spotify': 'https://open.s...
# 3  [{'external_urls': {'spotify': 'https://open.s...
# 4  [{'external_urls': {'spotify': 'https://open.s...
#
#                              track_available_markets  track_disc_number  \
# 0  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...                  1
# 1  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...                  1
# 2  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...                  1
# 3  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...                  1
# 4  [AD, AE, AL, AR, AT, AU, BA, BE, BG, BH, BO, B...                  1
#
#    track_duration_ms  track_explicit        track_external_ids  \
# 0             217650           False  {'isrc': 'JPWP01970489'}
# 1             203084           False  {'isrc': 'US5TA1400113'}
# 2             218120           False  {'isrc': 'KRA491000084'}
# 3             194535           False  {'isrc': 'US5TA1800023'}
# 4             195746           False  {'isrc': 'US5TA1700022'}
#
#                                  track_external_urls  \
# 0  {'spotify': 'https://open.spotify.com/track/5C...
# 1  {'spotify': 'https://open.spotify.com/track/3q...
# 2  {'spotify': 'https://open.spotify.com/track/6r...
# 3  {'spotify': 'https://open.spotify.com/track/1Z...
# 4  {'spotify': 'https://open.spotify.com/track/2d...
#
#                                           track_href                track_id  \
# 0  https://api.spotify.com/v1/tracks/5COO2JgOmHIJ...  5COO2JgOmHIJ2jsXFwflz8
# 1  https://api.spotify.com/v1/tracks/3qLNtf8mMhji...  3qLNtf8mMhjivYM84iVmy8
# 2  https://api.spotify.com/v1/tracks/6r2RWys84mPO...  6r2RWys84mPOYBMHXbrPZN
# 3  https://api.spotify.com/v1/tracks/1ZFQugO7BqYJ...  1ZFQugO7BqYJjw8FVQHcze
# 4  https://api.spotify.com/v1/tracks/2dYl2SI3sLyU...  2dYl2SI3sLyUffzxVBaZBz
#
#    track_is_local        track_name  track_popularity  \
# 0           False      Breakthrough                61
# 1           False  너란 Girl Magnetic                45
# 2           False   Better Together                37
# 3           False              Look                56
# 4           False       Knock Knock                62
#
#                                    track_preview_url  track_track_number  \
# 0  https://p.scdn.co/mp3-preview/cb9af41416965765...                   1
# 1  https://p.scdn.co/mp3-preview/c3dd3873b1bcab20...                   4
# 2  https://p.scdn.co/mp3-preview/8022dfb633858fa6...                   3
# 3  https://p.scdn.co/mp3-preview/0a45d1e590df117c...                   2
# 4                                               None                   1
#
#   track_type                             track_uri
# 0      track  spotify:track:5COO2JgOmHIJ2jsXFwflz8
# 1      track  spotify:track:3qLNtf8mMhjivYM84iVmy8
# 2      track  spotify:track:6r2RWys84mPOYBMHXbrPZN
# 3      track  spotify:track:1ZFQugO7BqYJjw8FVQHcze
# 4      track  spotify:track:2dYl2SI3sLyUffzxVBaZBz

# %%
# drop..
# 'track_album' - data is in album_info
# 'track_artists' - data is in artist_info
# 'track_available_markets', 'track_disc_number', 'track_explicit', 'track_is_local' - don't care about these
# 'track_type' - no useful info
# 
# + rename 'track_track_number' to 'track_number'

track_info.drop(['track_album', 'track_artists', 'track_available_markets',
                'track_disc_number', 'track_explicit', 'track_is_local', 'track_type'], 
                axis=1, inplace=True)
track_info.rename(columns={'track_track_number': 'track_number'}, inplace=True)

# %% [markdown]
# Now track, album, and artist dataframes are ready to be concatenated together

# %%
metadata = pd.concat([track_info, album_info, artist_info], axis=1)
metadata
# Out:
#            artist_track_name  track_duration_ms        track_external_ids  \
# 0        TWICE__Breakthrough             217650  {'isrc': 'JPWP01970489'}
# 1     GOT7__너란 Girl Magnetic             203084  {'isrc': 'US5TA1400113'}
# 2     SE7EN__Better Together             218120  {'isrc': 'KRA491000084'}
# 3                 GOT7__Look             194535  {'isrc': 'US5TA1800023'}
# 4         TWICE__KNOCK KNOCK             195746  {'isrc': 'US5TA1700022'}
# ...                      ...                ...                       ...
# 1471          Luvian__Forest             273307  {'isrc': 'USUS11600313'}
# 1472         BSS__Just do it             201757  {'isrc': 'KRA381704606'}
# 1473           ASTRO__Shadow             193609  {'isrc': 'KRA382050128'}
# 1474                 DAY6__君             192159  {'isrc': 'JPWP01971085'}
# 1475              DAY6__If ~             203493  {'isrc': 'JPWP01772931'}
#
#                                     track_external_urls  \
# 0     {'spotify': 'https://open.spotify.com/track/5C...
# 1     {'spotify': 'https://open.spotify.com/track/3q...
# 2     {'spotify': 'https://open.spotify.com/track/6r...
# 3     {'spotify': 'https://open.spotify.com/track/1Z...
# 4     {'spotify': 'https://open.spotify.com/track/2d...
# ...                                                 ...
# 1471  {'spotify': 'https://open.spotify.com/track/2k...
# 1472  {'spotify': 'https://open.spotify.com/track/57...
# 1473  {'spotify': 'https://open.spotify.com/track/5g...
# 1474  {'spotify': 'https://open.spotify.com/track/71...
# 1475  {'spotify': 'https://open.spotify.com/track/3o...
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5COO2JgOmHIJ...
# 1     https://api.spotify.com/v1/tracks/3qLNtf8mMhji...
# 2     https://api.spotify.com/v1/tracks/6r2RWys84mPO...
# 3     https://api.spotify.com/v1/tracks/1ZFQugO7BqYJ...
# 4     https://api.spotify.com/v1/tracks/2dYl2SI3sLyU...
# ...                                                 ...
# 1471  https://api.spotify.com/v1/tracks/2koAp3QuiVbf...
# 1472  https://api.spotify.com/v1/tracks/57ITlzpnOMkS...
# 1473  https://api.spotify.com/v1/tracks/5gXS4UeCGKuf...
# 1474  https://api.spotify.com/v1/tracks/71IelX1rq1Tq...
# 1475  https://api.spotify.com/v1/tracks/3oGtRoDWQpGJ...
#
#                     track_id        track_name  track_popularity  \
# 0     5COO2JgOmHIJ2jsXFwflz8      Breakthrough                61
# 1     3qLNtf8mMhjivYM84iVmy8  너란 Girl Magnetic                45
# 2     6r2RWys84mPOYBMHXbrPZN   Better Together                37
# 3     1ZFQugO7BqYJjw8FVQHcze              Look                56
# 4     2dYl2SI3sLyUffzxVBaZBz       Knock Knock                62
# ...                      ...               ...               ...
# 1471  2koAp3QuiVbfJ6tTu8ij2h            Forest                30
# 1472  57ITlzpnOMkSE6oHGbvTqi        Just do it                54
# 1473  5gXS4UeCGKufZGOGKyvJcM            Shadow                32
# 1474  71IelX1rq1TqK35DmH56XJ               君なら                38
# 1475  3oGtRoDWQpGJ0gtVkdD1V4       If 〜また逢えたら〜                41
#
#                                       track_preview_url  track_number  ...  \
# 0     https://p.scdn.co/mp3-preview/cb9af41416965765...             1  ...
# 1     https://p.scdn.co/mp3-preview/c3dd3873b1bcab20...             4  ...
# 2     https://p.scdn.co/mp3-preview/8022dfb633858fa6...             3  ...
# 3     https://p.scdn.co/mp3-preview/0a45d1e590df117c...             2  ...
# 4                                                  None             1  ...
# ...                                                 ...           ...  ...
# 1471  https://p.scdn.co/mp3-preview/45e1815b7a103e35...             4  ...
# 1472  https://p.scdn.co/mp3-preview/ea111e334ff61485...             1  ...
# 1473  https://p.scdn.co/mp3-preview/394c667c008f97f7...             1  ...
# 1474  https://p.scdn.co/mp3-preview/fad5c74ec156de9c...             2  ...
# 1475  https://p.scdn.co/mp3-preview/9f7488e385591cc5...             9  ...
#
#      album_release_date album_release_date_precision album_total_tracks  \
# 0            2019-06-12                          day                  1
# 1            2014-11-28                          day                 11
# 2                  2010                         year                  7
# 3            2018-03-12                          day                  6
# 4            2017-02-20                          day                  9
# ...                 ...                          ...                ...
# 1471         2016-07-29                          day                  5
# 1472         2018-03-21                          day                  1
# 1473         2018-01-29                          day                  1
# 1474         2019-12-04                          day                  4
# 1475         2018-10-17                          day                 10
#
#      album_type                             album_uri  \
# 0         album  spotify:album:7LWfEiSeue9BXPbUOH34q6
# 1         album  spotify:album:02dvCQbuBKdU1QHHGtrCHy
# 2         album  spotify:album:5WdFwkGiwtXM4DiXxl02CM
# 3         album  spotify:album:5aCJKuo69SGbveapvkSYMW
# 4         album  spotify:album:3O7HQtCnGoaXMxXLkspFL8
# ...         ...                                   ...
# 1471      album  spotify:album:4KQ1om2HjggigU8wiKTGnL
# 1472      album  spotify:album:7cL58mAH0Cs8giOqRNEjQP
# 1473      album  spotify:album:6Qhio1wu4IaAWKGH09Vmix
# 1474      album  spotify:album:1LDHf4VNXPeb7Q99QznE4h
# 1475      album  spotify:album:7INgr1F8dMMZyD7SEyq6E5
#
#                                    artist_external_urls  \
# 0     {'spotify': 'https://open.spotify.com/artist/7...
# 1     {'spotify': 'https://open.spotify.com/artist/6...
# 2     {'spotify': 'https://open.spotify.com/artist/1...
# 3     {'spotify': 'https://open.spotify.com/artist/6...
# 4     {'spotify': 'https://open.spotify.com/artist/7...
# ...                                                 ...
# 1471  {'spotify': 'https://open.spotify.com/artist/2...
# 1472  {'spotify': 'https://open.spotify.com/artist/1...
# 1473  {'spotify': 'https://open.spotify.com/artist/4...
# 1474  {'spotify': 'https://open.spotify.com/artist/5...
# 1475  {'spotify': 'https://open.spotify.com/artist/5...
#
#                                             artist_href  \
# 0     https://api.spotify.com/v1/artists/7n2Ycct7Bei...
# 1     https://api.spotify.com/v1/artists/6nfDaffa50m...
# 2     https://api.spotify.com/v1/artists/14yLuCwlBqt...
# 3     https://api.spotify.com/v1/artists/6nfDaffa50m...
# 4     https://api.spotify.com/v1/artists/7n2Ycct7Bei...
# ...                                                 ...
# 1471  https://api.spotify.com/v1/artists/25zpZzQN6Wn...
# 1472  https://api.spotify.com/v1/artists/1uAT5bTSp6d...
# 1473  https://api.spotify.com/v1/artists/4pz4uzOMpJQ...
# 1474  https://api.spotify.com/v1/artists/5TnQc2N1iKl...
# 1475  https://api.spotify.com/v1/artists/5TnQc2N1iKl...
#
#                    artist_id artist_name  \
# 0     7n2Ycct7Beij7Dj7meI4X0       TWICE
# 1     6nfDaffa50mKtEOwR8g4df        GOT7
# 2     14yLuCwlBqteUdBqx9soJV       SE7EN
# 3     6nfDaffa50mKtEOwR8g4df        GOT7
# 4     7n2Ycct7Beij7Dj7meI4X0       TWICE
# ...                      ...         ...
# 1471  25zpZzQN6WnNMt8LFtfsJW      Luvian
# 1472  1uAT5bTSp6dWbNmixIUP5t         BSS
# 1473  4pz4uzOMpJQyV8UTsDy4H8       ASTRO
# 1474  5TnQc2N1iKlFjYD7CPGvFc        DAY6
# 1475  5TnQc2N1iKlFjYD7CPGvFc        DAY6
#
#                                  artist_uri
# 0     spotify:artist:7n2Ycct7Beij7Dj7meI4X0
# 1     spotify:artist:6nfDaffa50mKtEOwR8g4df
# 2     spotify:artist:14yLuCwlBqteUdBqx9soJV
# 3     spotify:artist:6nfDaffa50mKtEOwR8g4df
# 4     spotify:artist:7n2Ycct7Beij7Dj7meI4X0
# ...                                     ...
# 1471  spotify:artist:25zpZzQN6WnNMt8LFtfsJW
# 1472  spotify:artist:1uAT5bTSp6dWbNmixIUP5t
# 1473  spotify:artist:4pz4uzOMpJQyV8UTsDy4H8
# 1474  spotify:artist:5TnQc2N1iKlFjYD7CPGvFc
# 1475  spotify:artist:5TnQc2N1iKlFjYD7CPGvFc
#
# [1476 rows x 29 columns]

# %% [markdown]
# ## Check for duplicates
# It's possible (likely) that some of the "unique" song names in metadata are actually duplicates. This was difficult to check earlier with just artist/track names, since the duplicates could result from any number of different variations (e.g., change in capitalization, or punctuation, or abbreviation, etc). But now, can at least check for any duplicate spotify IDs and fix them accordingly.

# %%
id_value_counts = metadata['track_id'].value_counts()
double_ids = id_value_counts[id_value_counts > 1]
double_ids
# Out:
# 4O4maU1Ki1PMaByGZqoC5g    2
# 2dYl2SI3sLyUffzxVBaZBz    2
# 1IX47gefluXmKX4PrTBCRM    2
# 5KawlOMHjWeUjQtnuRs22c    2
# 5HiSc2ZCGn8L3cH3qSwzBT    2
# Name: track_id, dtype: int64

# %%
print('{} songs are duplicated.'.format(len(double_ids)))
# Out:
# 5 songs are duplicated.

# %%
# get idxs of duplicate rows in metadata to delete
by_id = metadata.reset_index().set_index('track_id')
metadata_doubles = by_id.loc[double_ids.index, :]
metadata_doubles
# Out:
#                         index                        artist_track_name  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g    920  Brasstracks__Melanin Man (feat. Masego)
# 4O4maU1Ki1PMaByGZqoC5g    935                 Brasstracks__Melanin Man
# 2dYl2SI3sLyUffzxVBaZBz      4                       TWICE__KNOCK KNOCK
# 2dYl2SI3sLyUffzxVBaZBz    804                       TWICE__Knock Knock
# 1IX47gefluXmKX4PrTBCRM     19                     TWICE__What is Love?
# 1IX47gefluXmKX4PrTBCRM    772                      TWICE__What is Love
# 5KawlOMHjWeUjQtnuRs22c      5         BTS__Boy With Luv (feat. Halsey)
# 5KawlOMHjWeUjQtnuRs22c    714         BTS__Boy With Luv (Feat. Halsey)
# 5HiSc2ZCGn8L3cH3qSwzBT     41      Red Velvet__러시안 룰렛 Russian Roulette
# 5HiSc2ZCGn8L3cH3qSwzBT    455             Red Velvet__Russian Roulette
#
#                         track_duration_ms        track_external_ids  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g             250521  {'isrc': 'TCACR1607043'}
# 4O4maU1Ki1PMaByGZqoC5g             250521  {'isrc': 'TCACR1607043'}
# 2dYl2SI3sLyUffzxVBaZBz             195746  {'isrc': 'US5TA1700022'}
# 2dYl2SI3sLyUffzxVBaZBz             195746  {'isrc': 'US5TA1700022'}
# 1IX47gefluXmKX4PrTBCRM             208240  {'isrc': 'US5TA1800038'}
# 1IX47gefluXmKX4PrTBCRM             208240  {'isrc': 'US5TA1800038'}
# 5KawlOMHjWeUjQtnuRs22c             229773  {'isrc': 'QM6MZ1917908'}
# 5KawlOMHjWeUjQtnuRs22c             229773  {'isrc': 'QM6MZ1917908'}
# 5HiSc2ZCGn8L3cH3qSwzBT             211243  {'isrc': 'KRA301600315'}
# 5HiSc2ZCGn8L3cH3qSwzBT             211243  {'isrc': 'KRA301600315'}
#
#                                                       track_external_urls  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g  {'spotify': 'https://open.spotify.com/track/4O...
# 4O4maU1Ki1PMaByGZqoC5g  {'spotify': 'https://open.spotify.com/track/4O...
# 2dYl2SI3sLyUffzxVBaZBz  {'spotify': 'https://open.spotify.com/track/2d...
# 2dYl2SI3sLyUffzxVBaZBz  {'spotify': 'https://open.spotify.com/track/2d...
# 1IX47gefluXmKX4PrTBCRM  {'spotify': 'https://open.spotify.com/track/1I...
# 1IX47gefluXmKX4PrTBCRM  {'spotify': 'https://open.spotify.com/track/1I...
# 5KawlOMHjWeUjQtnuRs22c  {'spotify': 'https://open.spotify.com/track/5K...
# 5KawlOMHjWeUjQtnuRs22c  {'spotify': 'https://open.spotify.com/track/5K...
# 5HiSc2ZCGn8L3cH3qSwzBT  {'spotify': 'https://open.spotify.com/track/5H...
# 5HiSc2ZCGn8L3cH3qSwzBT  {'spotify': 'https://open.spotify.com/track/5H...
#
#                                                                track_href  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g  https://api.spotify.com/v1/tracks/4O4maU1Ki1PM...
# 4O4maU1Ki1PMaByGZqoC5g  https://api.spotify.com/v1/tracks/4O4maU1Ki1PM...
# 2dYl2SI3sLyUffzxVBaZBz  https://api.spotify.com/v1/tracks/2dYl2SI3sLyU...
# 2dYl2SI3sLyUffzxVBaZBz  https://api.spotify.com/v1/tracks/2dYl2SI3sLyU...
# 1IX47gefluXmKX4PrTBCRM  https://api.spotify.com/v1/tracks/1IX47gefluXm...
# 1IX47gefluXmKX4PrTBCRM  https://api.spotify.com/v1/tracks/1IX47gefluXm...
# 5KawlOMHjWeUjQtnuRs22c  https://api.spotify.com/v1/tracks/5KawlOMHjWeU...
# 5KawlOMHjWeUjQtnuRs22c  https://api.spotify.com/v1/tracks/5KawlOMHjWeU...
# 5HiSc2ZCGn8L3cH3qSwzBT  https://api.spotify.com/v1/tracks/5HiSc2ZCGn8L...
# 5HiSc2ZCGn8L3cH3qSwzBT  https://api.spotify.com/v1/tracks/5HiSc2ZCGn8L...
#
#                                          track_name  track_popularity  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g   Melanin Man (feat. Masego)                41
# 4O4maU1Ki1PMaByGZqoC5g   Melanin Man (feat. Masego)                41
# 2dYl2SI3sLyUffzxVBaZBz                  Knock Knock                62
# 2dYl2SI3sLyUffzxVBaZBz                  Knock Knock                62
# 1IX47gefluXmKX4PrTBCRM                 What is Love                73
# 1IX47gefluXmKX4PrTBCRM                 What is Love                73
# 5KawlOMHjWeUjQtnuRs22c  Boy With Luv (feat. Halsey)                84
# 5KawlOMHjWeUjQtnuRs22c  Boy With Luv (feat. Halsey)                84
# 5HiSc2ZCGn8L3cH3qSwzBT      러시안 룰렛 Russian Roulette                63
# 5HiSc2ZCGn8L3cH3qSwzBT      러시안 룰렛 Russian Roulette                63
#
#                                                         track_preview_url  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g  https://p.scdn.co/mp3-preview/6bd3ee77296d7c4b...
# 4O4maU1Ki1PMaByGZqoC5g  https://p.scdn.co/mp3-preview/6bd3ee77296d7c4b...
# 2dYl2SI3sLyUffzxVBaZBz                                               None
# 2dYl2SI3sLyUffzxVBaZBz                                               None
# 1IX47gefluXmKX4PrTBCRM                                               None
# 1IX47gefluXmKX4PrTBCRM                                               None
# 5KawlOMHjWeUjQtnuRs22c  https://p.scdn.co/mp3-preview/d16797fb391fb909...
# 5KawlOMHjWeUjQtnuRs22c  https://p.scdn.co/mp3-preview/d16797fb391fb909...
# 5HiSc2ZCGn8L3cH3qSwzBT  https://p.scdn.co/mp3-preview/80c7cca2fe309ce9...
# 5HiSc2ZCGn8L3cH3qSwzBT  https://p.scdn.co/mp3-preview/80c7cca2fe309ce9...
#
#                         track_number  ... album_release_date  \
# track_id                              ...
# 4O4maU1Ki1PMaByGZqoC5g             6  ...         2016-08-19
# 4O4maU1Ki1PMaByGZqoC5g             6  ...         2016-08-19
# 2dYl2SI3sLyUffzxVBaZBz             1  ...         2017-02-20
# 2dYl2SI3sLyUffzxVBaZBz             1  ...         2017-02-20
# 1IX47gefluXmKX4PrTBCRM             4  ...         2018-07-09
# 1IX47gefluXmKX4PrTBCRM             4  ...         2018-07-09
# 5KawlOMHjWeUjQtnuRs22c             2  ...         2019-04-12
# 5KawlOMHjWeUjQtnuRs22c             2  ...         2019-04-12
# 5HiSc2ZCGn8L3cH3qSwzBT             1  ...         2016-09-07
# 5HiSc2ZCGn8L3cH3qSwzBT             1  ...         2016-09-07
#
#                        album_release_date_precision album_total_tracks  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g                          day                  7
# 4O4maU1Ki1PMaByGZqoC5g                          day                  7
# 2dYl2SI3sLyUffzxVBaZBz                          day                  9
# 2dYl2SI3sLyUffzxVBaZBz                          day                  9
# 1IX47gefluXmKX4PrTBCRM                          day                  9
# 1IX47gefluXmKX4PrTBCRM                          day                  9
# 5KawlOMHjWeUjQtnuRs22c                          day                  7
# 5KawlOMHjWeUjQtnuRs22c                          day                  7
# 5HiSc2ZCGn8L3cH3qSwzBT                          day                  7
# 5HiSc2ZCGn8L3cH3qSwzBT                          day                  7
#
#                        album_type                             album_uri  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g      album  spotify:album:4dj2CRLWvdFgEzsVtc2qr6
# 4O4maU1Ki1PMaByGZqoC5g      album  spotify:album:4dj2CRLWvdFgEzsVtc2qr6
# 2dYl2SI3sLyUffzxVBaZBz      album  spotify:album:3O7HQtCnGoaXMxXLkspFL8
# 2dYl2SI3sLyUffzxVBaZBz      album  spotify:album:3O7HQtCnGoaXMxXLkspFL8
# 1IX47gefluXmKX4PrTBCRM      album  spotify:album:35LVzMbjGUCfYZYEP6YWyr
# 1IX47gefluXmKX4PrTBCRM      album  spotify:album:35LVzMbjGUCfYZYEP6YWyr
# 5KawlOMHjWeUjQtnuRs22c      album  spotify:album:1AvXa8xFEXtR3hb4bgihIK
# 5KawlOMHjWeUjQtnuRs22c      album  spotify:album:1AvXa8xFEXtR3hb4bgihIK
# 5HiSc2ZCGn8L3cH3qSwzBT      album  spotify:album:6MNlcai3skKLKv5syzFwC3
# 5HiSc2ZCGn8L3cH3qSwzBT      album  spotify:album:6MNlcai3skKLKv5syzFwC3
#
#                                                      artist_external_urls  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g  {'spotify': 'https://open.spotify.com/artist/5...
# 4O4maU1Ki1PMaByGZqoC5g  {'spotify': 'https://open.spotify.com/artist/5...
# 2dYl2SI3sLyUffzxVBaZBz  {'spotify': 'https://open.spotify.com/artist/7...
# 2dYl2SI3sLyUffzxVBaZBz  {'spotify': 'https://open.spotify.com/artist/7...
# 1IX47gefluXmKX4PrTBCRM  {'spotify': 'https://open.spotify.com/artist/7...
# 1IX47gefluXmKX4PrTBCRM  {'spotify': 'https://open.spotify.com/artist/7...
# 5KawlOMHjWeUjQtnuRs22c  {'spotify': 'https://open.spotify.com/artist/3...
# 5KawlOMHjWeUjQtnuRs22c  {'spotify': 'https://open.spotify.com/artist/3...
# 5HiSc2ZCGn8L3cH3qSwzBT  {'spotify': 'https://open.spotify.com/artist/1...
# 5HiSc2ZCGn8L3cH3qSwzBT  {'spotify': 'https://open.spotify.com/artist/1...
#
#                                                               artist_href  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g  https://api.spotify.com/v1/artists/5sKvgmG84C0...
# 4O4maU1Ki1PMaByGZqoC5g  https://api.spotify.com/v1/artists/5sKvgmG84C0...
# 2dYl2SI3sLyUffzxVBaZBz  https://api.spotify.com/v1/artists/7n2Ycct7Bei...
# 2dYl2SI3sLyUffzxVBaZBz  https://api.spotify.com/v1/artists/7n2Ycct7Bei...
# 1IX47gefluXmKX4PrTBCRM  https://api.spotify.com/v1/artists/7n2Ycct7Bei...
# 1IX47gefluXmKX4PrTBCRM  https://api.spotify.com/v1/artists/7n2Ycct7Bei...
# 5KawlOMHjWeUjQtnuRs22c  https://api.spotify.com/v1/artists/3Nrfpe0tUJi...
# 5KawlOMHjWeUjQtnuRs22c  https://api.spotify.com/v1/artists/3Nrfpe0tUJi...
# 5HiSc2ZCGn8L3cH3qSwzBT  https://api.spotify.com/v1/artists/1z4g3DjTBBZ...
# 5HiSc2ZCGn8L3cH3qSwzBT  https://api.spotify.com/v1/artists/1z4g3DjTBBZ...
#
#                                      artist_id  artist_name  \
# track_id
# 4O4maU1Ki1PMaByGZqoC5g  5sKvgmG84C0bIMWeS2SRPr  Brasstracks
# 4O4maU1Ki1PMaByGZqoC5g  5sKvgmG84C0bIMWeS2SRPr  Brasstracks
# 2dYl2SI3sLyUffzxVBaZBz  7n2Ycct7Beij7Dj7meI4X0        TWICE
# 2dYl2SI3sLyUffzxVBaZBz  7n2Ycct7Beij7Dj7meI4X0        TWICE
# 1IX47gefluXmKX4PrTBCRM  7n2Ycct7Beij7Dj7meI4X0        TWICE
# 1IX47gefluXmKX4PrTBCRM  7n2Ycct7Beij7Dj7meI4X0        TWICE
# 5KawlOMHjWeUjQtnuRs22c  3Nrfpe0tUJi4K4DXYWgMUX          BTS
# 5KawlOMHjWeUjQtnuRs22c  3Nrfpe0tUJi4K4DXYWgMUX          BTS
# 5HiSc2ZCGn8L3cH3qSwzBT  1z4g3DjTBBZKhvAroFlhOM   Red Velvet
# 5HiSc2ZCGn8L3cH3qSwzBT  1z4g3DjTBBZKhvAroFlhOM   Red Velvet
#
#                                                    artist_uri
# track_id
# 4O4maU1Ki1PMaByGZqoC5g  spotify:artist:5sKvgmG84C0bIMWeS2SRPr
# 4O4maU1Ki1PMaByGZqoC5g  spotify:artist:5sKvgmG84C0bIMWeS2SRPr
# 2dYl2SI3sLyUffzxVBaZBz  spotify:artist:7n2Ycct7Beij7Dj7meI4X0
# 2dYl2SI3sLyUffzxVBaZBz  spotify:artist:7n2Ycct7Beij7Dj7meI4X0
# 1IX47gefluXmKX4PrTBCRM  spotify:artist:7n2Ycct7Beij7Dj7meI4X0
# 1IX47gefluXmKX4PrTBCRM  spotify:artist:7n2Ycct7Beij7Dj7meI4X0
# 5KawlOMHjWeUjQtnuRs22c  spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX
# 5KawlOMHjWeUjQtnuRs22c  spotify:artist:3Nrfpe0tUJi4K4DXYWgMUX
# 5HiSc2ZCGn8L3cH3qSwzBT  spotify:artist:1z4g3DjTBBZKhvAroFlhOM
# 5HiSc2ZCGn8L3cH3qSwzBT  spotify:artist:1z4g3DjTBBZKhvAroFlhOM
#
# [10 rows x 29 columns]

# %%
# fix data_filt dataframe - duplicates should all have same name
# duplicates have same ID; doesn't really matter which name is kept, as long as they're all changed to that same one
def rename_duplicates(data_df, keep_name, change_name):
    keep_artist, keep_track = keep_name.split('__')    
    fix_these = data_df['artist_track_name'] == change_name
    
#     can this be consolidated?
    data_df.loc[fix_these, 'artist_track_name'] = keep_name
    data_df.loc[fix_these, 'artistName'] = keep_artist
    data_df.loc[fix_these, 'trackName'] = keep_track
    
    return data_df

data_copy = data_filt.copy()
for dup_id in double_ids.index:
    keep, change = by_id.loc[dup_id]['artist_track_name'].values
    data_copy = rename_duplicates(data_copy, keep, change)

# %%
# fix meta_data dataframe - delete duplicates
meta_copy = metadata.copy()
delete_these = metadata_doubles.iloc[1::2, :] #keep first match, delete second 
delete_these = delete_these['index'].values
meta_copy = meta_copy.drop(delete_these, axis=0).reset_index(drop=True)

# %%
data_filt = data_copy
metadata = meta_copy

# check - no more duplicate IDs
id_value_counts = metadata['track_id'].value_counts()
recheck_doubles = id_value_counts[id_value_counts > 1]
recheck_doubles
# Out:
# Series([], Name: track_id, dtype: int64)

# %%
# save
metadata.to_pickle('unique_song_metadata.pkl')
data_filt.to_pickle('filtered_song_data.pkl')

# %% [markdown]
# ## Use IDs in metadata df to get audio features for each unique song
# Use artist_id to get artist genre (album genre is often empty); use track_id to get audio features

# %%
# max 50 for single artists search
artist_ids = list(metadata['artist_id'])
artist_search = []
for start_idx in list(range(0, len(metadata), 50)):
    artist_search += sp.artists(artist_ids[start_idx:start_idx+50])['artists']

# get genres for each artist_search result    
artist_genres = [a['genres'] for a in artist_search]

# %%
# max 100 for single audio features search
track_ids = list(metadata['track_id'])
features_search = []
for start_idx in list(range(0, len(metadata), 100)):
    features_search += sp.audio_features(tracks=track_ids[start_idx:start_idx+100])

# %%
feature_data = pd.concat([metadata['artist_track_name'],
                          pd.Series(artist_genres, name='artist_genres'),
                          pd.DataFrame(features_search)], axis=1)
feature_data
# Out:
#            artist_track_name              artist_genres  danceability  energy  \
# 0        TWICE__Breakthrough  [k-pop, k-pop girl group]         0.868   0.728
# 1     GOT7__너란 Girl Magnetic   [k-pop, k-pop boy group]         0.720   0.870
# 2     SE7EN__Better Together                    [k-pop]         0.782   0.813
# 3                 GOT7__Look   [k-pop, k-pop boy group]         0.643   0.913
# 4         TWICE__KNOCK KNOCK  [k-pop, k-pop girl group]         0.673   0.968
# ...                      ...                        ...           ...     ...
# 1466          Luvian__Forest                         []         0.808   0.411
# 1467         BSS__Just do it                    [k-pop]         0.610   0.978
# 1468           ASTRO__Shadow   [k-pop, k-pop boy group]         0.763   0.905
# 1469                 DAY6__君   [k-pop, k-pop boy group]         0.552   0.949
# 1470              DAY6__If ~   [k-pop, k-pop boy group]         0.453   0.969
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 0       6    -3.338     0       0.1100      0.043900          0.000000
# 1       0    -4.129     0       0.0445      0.059600          0.000000
# 2       8    -3.788     1       0.0385      0.009710          0.000000
# 3       5    -1.724     0       0.1570      0.113000          0.000000
# 4       1    -2.636     0       0.1310      0.024200          0.000000
# ...   ...       ...   ...          ...           ...               ...
# 1466    9   -11.420     0       0.0837      0.431000          0.760000
# 1467    2    -2.432     1       0.1210      0.170000          0.000000
# 1468   11    -2.493     0       0.1020      0.066800          0.000000
# 1469   11    -2.580     0       0.0335      0.000581          0.000476
# 1470    4    -0.712     1       0.0962      0.024200          0.000014
#
#       liveness  valence    tempo            type                      id  \
# 0       0.0975    0.616  112.006  audio_features  5COO2JgOmHIJ2jsXFwflz8
# 1       0.3460    0.842  109.960  audio_features  3qLNtf8mMhjivYM84iVmy8
# 2       0.3440    0.788  119.998  audio_features  6r2RWys84mPOYBMHXbrPZN
# 3       0.3830    0.734  119.938  audio_features  1ZFQugO7BqYJjw8FVQHcze
# 4       0.0587    0.476  129.972  audio_features  2dYl2SI3sLyUffzxVBaZBz
# ...        ...      ...      ...             ...                     ...
# 1466    0.1200    0.152  103.020  audio_features  2koAp3QuiVbfJ6tTu8ij2h
# 1467    0.3920    0.815  150.047  audio_features  57ITlzpnOMkSE6oHGbvTqi
# 1468    0.0594    0.811  118.015  audio_features  5gXS4UeCGKufZGOGKyvJcM
# 1469    0.2900    0.615  131.969  audio_features  71IelX1rq1TqK35DmH56XJ
# 1470    0.0410    0.560  188.015  audio_features  3oGtRoDWQpGJ0gtVkdD1V4
#
#                                        uri  \
# 0     spotify:track:5COO2JgOmHIJ2jsXFwflz8
# 1     spotify:track:3qLNtf8mMhjivYM84iVmy8
# 2     spotify:track:6r2RWys84mPOYBMHXbrPZN
# 3     spotify:track:1ZFQugO7BqYJjw8FVQHcze
# 4     spotify:track:2dYl2SI3sLyUffzxVBaZBz
# ...                                    ...
# 1466  spotify:track:2koAp3QuiVbfJ6tTu8ij2h
# 1467  spotify:track:57ITlzpnOMkSE6oHGbvTqi
# 1468  spotify:track:5gXS4UeCGKufZGOGKyvJcM
# 1469  spotify:track:71IelX1rq1TqK35DmH56XJ
# 1470  spotify:track:3oGtRoDWQpGJ0gtVkdD1V4
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/5COO2JgOmHIJ...
# 1     https://api.spotify.com/v1/tracks/3qLNtf8mMhji...
# 2     https://api.spotify.com/v1/tracks/6r2RWys84mPO...
# 3     https://api.spotify.com/v1/tracks/1ZFQugO7BqYJ...
# 4     https://api.spotify.com/v1/tracks/2dYl2SI3sLyU...
# ...                                                 ...
# 1466  https://api.spotify.com/v1/tracks/2koAp3QuiVbf...
# 1467  https://api.spotify.com/v1/tracks/57ITlzpnOMkS...
# 1468  https://api.spotify.com/v1/tracks/5gXS4UeCGKuf...
# 1469  https://api.spotify.com/v1/tracks/71IelX1rq1Tq...
# 1470  https://api.spotify.com/v1/tracks/3oGtRoDWQpGJ...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/5COO...       217651
# 1     https://api.spotify.com/v1/audio-analysis/3qLN...       203084
# 2     https://api.spotify.com/v1/audio-analysis/6r2R...       218120
# 3     https://api.spotify.com/v1/audio-analysis/1ZFQ...       194535
# 4     https://api.spotify.com/v1/audio-analysis/2dYl...       195747
# ...                                                 ...          ...
# 1466  https://api.spotify.com/v1/audio-analysis/2koA...       273307
# 1467  https://api.spotify.com/v1/audio-analysis/57IT...       201758
# 1468  https://api.spotify.com/v1/audio-analysis/5gXS...       193609
# 1469  https://api.spotify.com/v1/audio-analysis/71Ie...       192159
# 1470  https://api.spotify.com/v1/audio-analysis/3oGt...       203493
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 1466               4
# 1467               4
# 1468               4
# 1469               4
# 1470               4
#
# [1471 rows x 20 columns]

# %%
# keep feature info only; most of the other ID stuff is already in meta_data
feature_data.drop(['type', 'id', 'uri', 'track_href', 'analysis_url'], axis=1, inplace=True)
feature_data.head()
# Out:
#         artist_track_name              artist_genres  danceability  energy  \
# 0     TWICE__Breakthrough  [k-pop, k-pop girl group]         0.868   0.728
# 1  GOT7__너란 Girl Magnetic   [k-pop, k-pop boy group]         0.720   0.870
# 2  SE7EN__Better Together                    [k-pop]         0.782   0.813
# 3              GOT7__Look   [k-pop, k-pop boy group]         0.643   0.913
# 4      TWICE__KNOCK KNOCK  [k-pop, k-pop girl group]         0.673   0.968
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    6    -3.338     0       0.1100       0.04390               0.0    0.0975
# 1    0    -4.129     0       0.0445       0.05960               0.0    0.3460
# 2    8    -3.788     1       0.0385       0.00971               0.0    0.3440
# 3    5    -1.724     0       0.1570       0.11300               0.0    0.3830
# 4    1    -2.636     0       0.1310       0.02420               0.0    0.0587
#
#    valence    tempo  duration_ms  time_signature
# 0    0.616  112.006       217651               4
# 1    0.842  109.960       203084               4
# 2    0.788  119.998       218120               4
# 3    0.734  119.938       194535               4
# 4    0.476  129.972       195747               4

# %%
#  save
feature_data.to_pickle('song_feature_data.pkl')
